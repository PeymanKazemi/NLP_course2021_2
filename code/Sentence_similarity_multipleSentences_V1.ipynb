# %% [markdown]
# <a href="https://colab.research.google.com/github/PeymanKazemi/NLP_course2021_2/blob/main/code/NLP_sentence_similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A dependency of the preprocessing for BERT inputs
# !pip install -q -U tensorflow-text
# Out:
#      |████████████████████████████████| 4.9 MB 1.6 MB/s

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.4 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 51.8 MB/s
# ...
#      |████████████████████████████████| 895 kB 49.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 41.9 MB/s
# ...
#      |████████████████████████████████| 61 kB 426 kB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install sentence_transformers
# Out:
# ...
#      |████████████████████████████████| 78 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 3.1 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=9e46707cd7d7dc8b70cc5ee916e5e3cdcaed3b462d99671d7a79d21703e78dce
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built sentence-transformers
# ...

# %% [markdown]
# Using more than one sentence as input

# %%
from sentence_transformers import SentenceTransformer, util
from transformers import AutoTokenizer, AutoModelForSequenceClassification

sentence01 = ["life is beautifull. life is loveable."]
sentence02 = ["life is not good. I don't like life."]

model = SentenceTransformer('sentence-transformers/distiluse-base-multilingual-cased-v2')

'''
classifier = ("sentence_transformers",model, tokenizer = tokenizer)
results = (["life is beautifull", "life is great"])

for result in results:
  print(result)
'''
#encode_sentence01 = tokenizer(sentence01)
#encode_sentence02 = tokenizer(sentence02)

emb01 =  model.encode(sentence01)
emb02 =  model.encode(sentence02)
#print(encode_sentence01)

cos_similarity = util.cos_sim(emb01, emb02)
print("Cosine-Similarity:", cos_similarity)
# embeddings = model.encode(sentence01)
# print(embeddings)

'''
#Sentences are encoded by calling model.encode()
emb01 = model.encode(sentence01)
emb02 = model.encode(sentence02)

cos_sim = util.cos_sim(emb01, emb02)
print("Cosine-Similarity:", cos_sim)
'''
# Out:
# Cosine-Similarity: tensor([[0.6881]])
# '\n#Sentences are encoded by calling model.encode()\nemb01 = model.encode(sentence01)\nemb02 = model.encode(sentence02)\n\ncos_sim = util.cos_sim(emb01, emb02)\nprint("Cosine-Similarity:", cos_sim)\n'

# %%
from sentence_transformers import SentenceTransformer, util
sentences = ["life is beautifull", "life is great"]
model = SentenceTransformer('sentence-transformers/distiluse-base-multilingual-cased-v2')
embeddings = model.encode(sentences)
# print(embeddings)


#Sentences are encoded by calling model.encode()
emb3 = model.encode(sentences[0])
emb4 = model.encode(sentences[1])

cos_sim01 = util.cos_sim(emb3, emb4)
print("Cosine-Similarity:", cos_sim01)
print(sentences[0])
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/610 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/341 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/539M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/531 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/114 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# Cosine-Similarity: tensor([[0.8471]])
# life is beautifull

# %% [markdown]
# **find the best similarity between couple of sentences**

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('sentence-transformers/distiluse-base-multilingual-cased')

sentences = ['A man is eating food.',
          'A man is eating a piece of bread.',
          'The girl is carrying a baby.',
          'A man is riding a horse.',
          'A woman is playing violin.',
          'Two men pushed carts through the woods.',
          'A man is riding a white horse on an enclosed ground.',
          'A monkey is playing drums.',
          'Someone in a gorilla costume is playing a set of drums.'
          ]

#Encode all sentences
embeddings = model.encode(sentences)

#Compute cosine similarity between all pairs
cos_sim = util.cos_sim(embeddings, embeddings)

#Add all pairs to a list with their cosine similarity score
all_sentence_combinations = []
for i in range(len(cos_sim)-1):
    for j in range(i+1, len(cos_sim)):
        all_sentence_combinations.append([cos_sim[i][j], i, j])

#Sort list by the highest cosine similarity score
all_sentence_combinations = sorted(all_sentence_combinations, key=lambda x: x[0], reverse=True)

print("Top-5 most similar pairs:")
for score, i, j in all_sentence_combinations[0:5]:
    print("{} \t {} \t {:.4f}".format(sentences[i], sentences[j], cos_sim[i][j]))
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.37k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/607 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/341 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/539M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/528 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/114 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# Top-5 most similar pairs:
# A monkey is playing drums. 	 Someone in a gorilla costume is playing a set of drums. 	 0.7512
# ...
